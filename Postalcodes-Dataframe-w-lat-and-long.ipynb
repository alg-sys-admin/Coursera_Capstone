# %% [markdown]
# #### Now that you have built a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name, in order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood.
#
# #### Given that this package can be very unreliable, in case you are not able to get the geographical coordinates of the neighborhoods using the Geocoder package, here is a link to a csv file that has the geographical coordinates of each postal code: http://cocl.us/Geospatial_data
#
# #### Use the Geocoder package or the csv file to create the following dataframe:
#
# #### (Used the csv file provided)

# %%
import pandas as pd
url = "https://cocl.us/Geospatial_data"
latlng_df = pd.read_csv(url)

# %% [markdown]
# #### Quick check

# %%
latlng_df.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
latlng_df.tail()
# Out:
#     Postal Code   Latitude  Longitude
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054

# %% [markdown]
# #### Dataframe from previous exercise was exported to a csv file and uploaded to Github

# %%
url2 = 'https://raw.githubusercontent.com/alg-sys-admin/Coursera_Capstone/master/Postcodes.csv'
Postcodes_DF = pd.read_csv(url2, index_col=0)

# %% [markdown]
# #### Quick check

# %%
Postcodes_DF.head()
# Out:
#               Borough                         Neighbourhood
# Postcode
# M1B       Scarborough                         Rouge,Malvern
# M1C       Scarborough  Highland Creek,Rouge Hill,Port Union
# M1E       Scarborough       Guildwood,Morningside,West Hill
# M1G       Scarborough                                Woburn
# M1H       Scarborough                             Cedarbrae

# %%
Postcodes_DF.tail()
# Out:
#             Borough                                      Neighbourhood
# Postcode
# M9N            York                                             Weston
# M9P       Etobicoke                                          Westmount
# M9R       Etobicoke  Kingsview Village,Martin Grove Gardens,Richvie...
# M9V       Etobicoke  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# M9W       Etobicoke                                          Northwest

# %% [markdown]
# #### Check Column Names

# %%
print(Postcodes_DF.columns)
# Out:
# Index(['Borough', 'Neighbourhood'], dtype='object')

# %%
print(latlng_df.columns)
# Out:
# Index(['Postal Code', 'Latitude', 'Longitude'], dtype='object')

# %% [markdown]
# #### Rename column to match the column name in the other dataframe

# %%
latlng_df.rename({'Postal Code': 'Postcode'}, axis=1, inplace=True)

# %% [markdown]
# #### quick check

# %%
print(latlng_df.columns)
# Out:
# Index(['Postcode', 'Latitude', 'Longitude'], dtype='object')

# %% [markdown]
# #### Merge Dataframes on Postal Codes Column

# %%
Combined_DF = pd.merge(Postcodes_DF, latlng_df, on='Postcode').copy()

# %% [markdown]
# #### Quick check

# %%
Combined_DF.head()
# Out:
#   Postcode      Borough                         Neighbourhood   Latitude  \
# 0      M1B  Scarborough                         Rouge,Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek,Rouge Hill,Port Union  43.784535
# 2      M1E  Scarborough       Guildwood,Morningside,West Hill  43.763573
# 3      M1G  Scarborough                                Woburn  43.770992
# 4      M1H  Scarborough                             Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
Combined_DF.tail()
# Out:
#     Postcode    Borough                                      Neighbourhood  \
# 98       M9N       York                                             Weston
# 99       M9P  Etobicoke                                          Westmount
# 100      M9R  Etobicoke  Kingsview Village,Martin Grove Gardens,Richvie...
# 101      M9V  Etobicoke  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 102      M9W  Etobicoke                                          Northwest
#
#       Latitude  Longitude
# 98   43.706876 -79.518188
# 99   43.696319 -79.532242
# 100  43.688905 -79.554724
# 101  43.739416 -79.588437
# 102  43.706748 -79.594054

# %% [markdown]
# #### Shape should be the same as before
# ##### (Previous exercise had shape as the last insruction)

# %%
Combined_DF.shape
# Out:
# (103, 5)

# %% [markdown]
# #### Since the dataframe is small, iterate through the rows to check for discrepancies

# %%
for (index_label, row_series) in Combined_DF.iterrows():
   print('Row: ', index_label, 'Data: ', row_series.values)
# Out:
# Row:  0 Data:  ['M1B' 'Scarborough' 'Rouge,Malvern' 43.806686299999996 -79.19435340000001]
# Row:  1 Data:  ['M1C' 'Scarborough' 'Highland Creek,Rouge Hill,Port Union' 43.7845351
#  -79.16049709999999]
# Row:  2 Data:  ['M1E' 'Scarborough' 'Guildwood,Morningside,West Hill' 43.7635726
#  -79.1887115]
# Row:  3 Data:  ['M1G' 'Scarborough' 'Woburn' 43.7709921 -79.21691740000001]
# Row:  4 Data:  ['M1H' 'Scarborough' 'Cedarbrae' 43.773136 -79.23947609999999]
# Row:  5 Data:  ['M1J' 'Scarborough' 'Scarborough Village' 43.7447342 -79.23947609999999]
# Row:  6 Data:  ['M1K' 'Scarborough' 'East Birchmount Park,Ionview,Kennedy Park'
#  43.7279292 -79.26202940000002]
# Row:  7 Data:  ['M1L' 'Scarborough' 'Clairlea,Golden Mile,Oakridge' 43.711111700000004
#  -79.2845772]
# Row:  8 Data:  ['M1M' 'Scarborough' 'Cliffcrest,Cliffside,Scarborough Village West'
#  43.716316 -79.23947609999999]
# Row:  9 Data:  ['M1N' 'Scarborough' 'Birch Cliff,Cliffside West' 43.692657000000004
#  -79.2648481]
# Row:  10 Data:  ['M1P' 'Scarborough' 'Dorset Park,Scarborough Town Centre,Wexford Heights'
#  43.7574096 -79.27330400000001]
# Row:  11 Data:  ['M1R' 'Scarborough' 'Maryvale,Wexford' 43.750071500000004 -79.2958491]
# Row:  12 Data:  ['M1S' 'Scarborough' 'Agincourt' 43.7942003 -79.26202940000002]
# Row:  13 Data:  ['M1T' 'Scarborough' "Clarks Corners,Sullivan,Tam O'Shanter" 43.7816375
#  -79.3043021]
# Row:  14 Data:  ['M1V' 'Scarborough'
#  "Agincourt North,L'Amoreaux East,Milliken,Steeles East" 43.8152522
#  -79.2845772]
# Row:  15 Data:  ['M1W' 'Scarborough' "L'Amoreaux West" 43.799525200000005 -79.3183887]
# Row:  16 Data:  ['M1X' 'Scarborough' 'Upper Rouge' 43.836124700000006 -79.20563609999999]
# Row:  17 Data:  ['M2H' 'North York' 'Hillcrest Village' 43.8037622 -79.3634517]
# Row:  18 Data:  ['M2J' 'North York' 'Fairview,Henry Farm,Oriole' 43.7785175 -79.3465557]
# Row:  19 Data:  ['M2K' 'North York' 'Bayview Village' 43.7869473 -79.385975]
# Row:  20 Data:  ['M2L' 'North York' 'Silver Hills,York Mills' 43.7574902
#  -79.37471409999999]
# Row:  21 Data:  ['M2M' 'North York' 'Newtonbrook,Willowdale' 43.789053 -79.40849279999999]
# Row:  22 Data:  ['M2N' 'North York' 'Willowdale South' 43.7701199 -79.40849279999999]
# Row:  23 Data:  ['M2P' 'North York' 'York Mills West' 43.752758299999996 -79.4000493]
# Row:  24 Data:  ['M2R' 'North York' 'Willowdale West' 43.7827364 -79.4422593]
# Row:  25 Data:  ['M3A' 'North York' 'Parkwoods' 43.7532586 -79.3296565]
# Row:  26 Data:  ['M3B' 'North York' 'Don Mills North' 43.745905799999996 -79.352188]
# Row:  27 Data:  ['M3C' 'North York' 'Flemingdon Park,Don Mills South' 43.72589970000001
#  -79.340923]
# Row:  28 Data:  ['M3H' 'North York' 'Bathurst Manor,Downsview North,Wilson Heights'
#  43.7543283 -79.4422593]
# Row:  29 Data:  ['M3J' 'North York' 'Northwood Park,York University' 43.7679803
#  -79.48726190000001]
# Row:  30 Data:  ['M3K' 'North York' 'CFB Toronto,Downsview East' 43.737473200000004
#  -79.46476329999999]
# Row:  31 Data:  ['M3L' 'North York' 'Downsview West' 43.7390146 -79.5069436]
# Row:  32 Data:  ['M3M' 'North York' 'Downsview Central' 43.7284964 -79.49569740000001]
# Row:  33 Data:  ['M3N' 'North York' 'Downsview Northwest' 43.7616313 -79.52099940000001]
# Row:  34 Data:  ['M4A' 'North York' 'Victoria Village' 43.725882299999995
#  -79.31557159999998]
# Row:  35 Data:  ['M4B' 'East York' 'Woodbine Gardens,Parkview Hill' 43.7063972 -79.309937]
# Row:  36 Data:  ['M4C' 'East York' 'Woodbine Heights' 43.695343900000005 -79.3183887]
# Row:  37 Data:  ['M4E' 'East Toronto' 'The Beaches' 43.67635739999999 -79.2930312]
# Row:  38 Data:  ['M4G' 'East York' 'Leaside' 43.7090604 -79.3634517]
# Row:  39 Data:  ['M4H' 'East York' 'Thorncliffe Park' 43.7053689 -79.34937190000001]
# Row:  40 Data:  ['M4J' 'East York' 'East Toronto' 43.685347 -79.3381065]
# Row:  41 Data:  ['M4K' 'East Toronto' 'The Danforth West,Riverdale' 43.6795571 -79.352188]
# Row:  42 Data:  ['M4L' 'East Toronto' 'The Beaches West,India Bazaar' 43.6689985
#  -79.31557159999998]
# Row:  43 Data:  ['M4M' 'East Toronto' 'Studio District' 43.6595255 -79.340923]
# Row:  44 Data:  ['M4N' 'Central Toronto' 'Lawrence Park' 43.7280205 -79.3887901]
# Row:  45 Data:  ['M4P' 'Central Toronto' 'Davisville North' 43.7127511 -79.3901975]
# Row:  46 Data:  ['M4R' 'Central Toronto' 'North Toronto West' 43.7153834
#  -79.40567840000001]
# Row:  47 Data:  ['M4S' 'Central Toronto' 'Davisville' 43.7043244 -79.3887901]
# Row:  48 Data:  ['M4T' 'Central Toronto' 'Moore Park,Summerhill East' 43.6895743
#  -79.38315990000001]
# Row:  49 Data:  ['M4V' 'Central Toronto'
#  'Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West'
#  43.68641229999999 -79.4000493]
# Row:  50 Data:  ['M4W' 'Downtown Toronto' 'Rosedale' 43.6795626 -79.37752940000001]
# Row:  51 Data:  ['M4X' 'Downtown Toronto' 'Cabbagetown,St. James Town' 43.667967
#  -79.3676753]
# Row:  52 Data:  ['M4Y' 'Downtown Toronto' 'Church and Wellesley' 43.6658599
#  -79.38315990000001]
# Row:  53 Data:  ['M5A' 'Downtown Toronto' 'Harbourfront,Regent Park' 43.6542599
#  -79.3606359]
# Row:  54 Data:  ['M5B' 'Downtown Toronto' 'Ryerson,Garden District' 43.6571618
#  -79.37893709999999]
# Row:  55 Data:  ['M5C' 'Downtown Toronto' 'St. James Town' 43.6514939 -79.3754179]
# Row:  56 Data:  ['M5E' 'Downtown Toronto' 'Berczy Park' 43.644770799999996 -79.3733064]
# Row:  57 Data:  ['M5G' 'Downtown Toronto' 'Central Bay Street' 43.6579524 -79.3873826]
# Row:  58 Data:  ['M5H' 'Downtown Toronto' 'Adelaide,King,Richmond' 43.65057120000001
#  -79.3845675]
# Row:  59 Data:  ['M5J' 'Downtown Toronto'
#  'Harbourfront East,Toronto Islands,Union Station' 43.6408157
#  -79.38175229999999]
# Row:  60 Data:  ['M5K' 'Downtown Toronto' 'Design Exchange,Toronto Dominion Centre'
#  43.6471768 -79.38157640000001]
# Row:  61 Data:  ['M5L' 'Downtown Toronto' 'Commerce Court,Victoria Hotel' 43.6481985
#  -79.37981690000001]
# Row:  62 Data:  ['M5M' 'North York' 'Bedford Park,Lawrence Manor East' 43.7332825
#  -79.4197497]
# Row:  63 Data:  ['M5N' 'Central Toronto' 'Roselawn' 43.7116948 -79.41693559999999]
# Row:  64 Data:  ['M5P' 'Central Toronto' 'Forest Hill North,Forest Hill West' 43.6969476
#  -79.41130720000001]
# Row:  65 Data:  ['M5R' 'Central Toronto' 'The Annex,North Midtown,Yorkville' 43.6727097
#  -79.40567840000001]
# Row:  66 Data:  ['M5S' 'Downtown Toronto' 'Harbord,University of Toronto' 43.6626956
#  -79.4000493]
# Row:  67 Data:  ['M5T' 'Downtown Toronto' 'Chinatown,Grange Park,Kensington Market'
#  43.6532057 -79.4000493]
# Row:  68 Data:  ['M5V' 'Downtown Toronto'
#  'CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara'
#  43.6289467 -79.3944199]
# Row:  69 Data:  ['M5W' 'Downtown Toronto' 'Stn A PO Boxes 25 The Esplanade' 43.6464352
#  -79.37484599999999]
# Row:  70 Data:  ['M5X' 'Downtown Toronto' 'First Canadian Place,Underground city'
#  43.6484292 -79.3822802]
# Row:  71 Data:  ['M6A' 'North York' 'Lawrence Heights,Lawrence Manor' 43.718517999999996
#  -79.46476329999999]
# Row:  72 Data:  ['M6B' 'North York' 'Glencairn' 43.709577 -79.44507259999999]
# Row:  73 Data:  ['M6C' 'York' 'Humewood-Cedarvale' 43.6937813 -79.42819140000002]
# Row:  74 Data:  ['M6E' 'York' 'Caledonia-Fairbanks' 43.6890256 -79.453512]
# Row:  75 Data:  ['M6G' 'Downtown Toronto' 'Christie' 43.669542 -79.4225637]
# Row:  76 Data:  ['M6H' 'West Toronto' 'Dovercourt Village,Dufferin' 43.66900510000001
#  -79.4422593]
# Row:  77 Data:  ['M6J' 'West Toronto' 'Little Portugal,Trinity' 43.647926700000006
#  -79.4197497]
# Row:  78 Data:  ['M6K' 'West Toronto' 'Brockton,Exhibition Place,Parkdale Village'
#  43.6368472 -79.42819140000002]
# Row:  79 Data:  ['M6L' 'North York' 'Downsview,North Park,Upwood Park' 43.713756200000006
#  -79.4900738]
# Row:  80 Data:  ['M6M' 'York' 'Del Ray,Keelesdale,Mount Dennis,Silverthorn' 43.6911158
#  -79.47601329999999]
# Row:  81 Data:  ['M6N' 'York' 'The Junction North,Runnymede' 43.67318529999999
#  -79.48726190000001]
# Row:  82 Data:  ['M6P' 'West Toronto' 'High Park,The Junction South' 43.6616083
#  -79.46476329999999]
# Row:  83 Data:  ['M6R' 'West Toronto' 'Parkdale,Roncesvalles' 43.6489597 -79.456325]
# Row:  84 Data:  ['M6S' 'West Toronto' 'Runnymede,Swansea' 43.6515706 -79.4844499]
# Row:  85 Data:  ['M7A' "Queen's Park" "Queen's Park" 43.6623015 -79.3894938]
# Row:  86 Data:  ['M7R' 'Mississauga' 'Canada Post Gateway Processing Centre' 43.6369656
#  -79.61581899999999]
# Row:  87 Data:  ['M7Y' 'East Toronto' 'Business Reply Mail Processing Centre 969 Eastern'
#  43.6627439 -79.321558]
# Row:  88 Data:  ['M8V' 'Etobicoke' 'Humber Bay Shores,Mimico South,New Toronto' 43.6056466
#  -79.50132070000001]
# Row:  89 Data:  ['M8W' 'Etobicoke' 'Alderwood,Long Branch' 43.60241370000001
#  -79.54348409999999]
# Row:  90 Data:  ['M8X' 'Etobicoke' 'The Kingsway,Montgomery Road,Old Mill North'
#  43.653653600000005 -79.5069436]
# Row:  91 Data:  ['M8Y' 'Etobicoke'
#  "Humber Bay,King's Mill Park,Kingsway Park South East,Mimico NE,Old Mill South,The Queensway East,Royal York South East,Sunnylea"
#  43.6362579 -79.49850909999999]
# Row:  92 Data:  ['M8Z' 'Etobicoke'
#  'Kingsway Park South West,Mimico NW,The Queensway West,Royal York South West,South of Bloor'
#  43.6288408 -79.52099940000001]
# Row:  93 Data:  ['M9A' 'Etobicoke' 'Islington Avenue' 43.6678556 -79.53224240000002]
# Row:  94 Data:  ['M9B' 'Etobicoke'
#  'Cloverdale,Islington,Martin Grove,Princess Gardens,West Deane Park'
#  43.6509432 -79.55472440000001]
# Row:  95 Data:  ['M9C' 'Etobicoke'
#  'Bloordale Gardens,Eringate,Markland Wood,Old Burnhamthorpe' 43.6435152
#  -79.57720079999999]
# Row:  96 Data:  ['M9L' 'North York' 'Humber Summit' 43.7563033 -79.56596329999999]
# Row:  97 Data:  ['M9M' 'North York' 'Emery,Humberlea' 43.7247659 -79.53224240000002]
# Row:  98 Data:  ['M9N' 'York' 'Weston' 43.706876 -79.51818840000001]
# Row:  99 Data:  ['M9P' 'Etobicoke' 'Westmount' 43.696319 -79.53224240000002]
# Row:  100 Data:  ['M9R' 'Etobicoke'
#  'Kingsview Village,Martin Grove Gardens,Richview Gardens,St. Phillips'
#  43.6889054 -79.55472440000001]
# Row:  101 Data:  ['M9V' 'Etobicoke'
#  'Albion Gardens,Beaumond Heights,Humbergate,Jamestown,Mount Olive,Silverstone,South Steeles,Thistletown'
#  43.739416399999996 -79.5884369]
# Row:  102 Data:  ['M9W' 'Etobicoke' 'Northwest' 43.706748299999994 -79.5940544]

# %%
for namedTuple in Combined_DF.itertuples():
   print(namedTuple)
# Out:
# Pandas(Index=0, Postcode='M1B', Borough='Scarborough', Neighbourhood='Rouge,Malvern', Latitude=43.806686299999996, Longitude=-79.19435340000001)
# Pandas(Index=1, Postcode='M1C', Borough='Scarborough', Neighbourhood='Highland Creek,Rouge Hill,Port Union', Latitude=43.7845351, Longitude=-79.16049709999999)
# Pandas(Index=2, Postcode='M1E', Borough='Scarborough', Neighbourhood='Guildwood,Morningside,West Hill', Latitude=43.7635726, Longitude=-79.1887115)
# Pandas(Index=3, Postcode='M1G', Borough='Scarborough', Neighbourhood='Woburn', Latitude=43.7709921, Longitude=-79.21691740000001)
# Pandas(Index=4, Postcode='M1H', Borough='Scarborough', Neighbourhood='Cedarbrae', Latitude=43.773136, Longitude=-79.23947609999999)
# Pandas(Index=5, Postcode='M1J', Borough='Scarborough', Neighbourhood='Scarborough Village', Latitude=43.7447342, Longitude=-79.23947609999999)
# Pandas(Index=6, Postcode='M1K', Borough='Scarborough', Neighbourhood='East Birchmount Park,Ionview,Kennedy Park', Latitude=43.7279292, Longitude=-79.26202940000002)
# Pandas(Index=7, Postcode='M1L', Borough='Scarborough', Neighbourhood='Clairlea,Golden Mile,Oakridge', Latitude=43.711111700000004, Longitude=-79.2845772)
# Pandas(Index=8, Postcode='M1M', Borough='Scarborough', Neighbourhood='Cliffcrest,Cliffside,Scarborough Village West', Latitude=43.716316, Longitude=-79.23947609999999)
# Pandas(Index=9, Postcode='M1N', Borough='Scarborough', Neighbourhood='Birch Cliff,Cliffside West', Latitude=43.692657000000004, Longitude=-79.2648481)
# Pandas(Index=10, Postcode='M1P', Borough='Scarborough', Neighbourhood='Dorset Park,Scarborough Town Centre,Wexford Heights', Latitude=43.7574096, Longitude=-79.27330400000001)
# Pandas(Index=11, Postcode='M1R', Borough='Scarborough', Neighbourhood='Maryvale,Wexford', Latitude=43.750071500000004, Longitude=-79.2958491)
# Pandas(Index=12, Postcode='M1S', Borough='Scarborough', Neighbourhood='Agincourt', Latitude=43.7942003, Longitude=-79.26202940000002)
# Pandas(Index=13, Postcode='M1T', Borough='Scarborough', Neighbourhood="Clarks Corners,Sullivan,Tam O'Shanter", Latitude=43.7816375, Longitude=-79.3043021)
# Pandas(Index=14, Postcode='M1V', Borough='Scarborough', Neighbourhood="Agincourt North,L'Amoreaux East,Milliken,Steeles East", Latitude=43.8152522, Longitude=-79.2845772)
# Pandas(Index=15, Postcode='M1W', Borough='Scarborough', Neighbourhood="L'Amoreaux West", Latitude=43.799525200000005, Longitude=-79.3183887)
# Pandas(Index=16, Postcode='M1X', Borough='Scarborough', Neighbourhood='Upper Rouge', Latitude=43.836124700000006, Longitude=-79.20563609999999)
# Pandas(Index=17, Postcode='M2H', Borough='North York', Neighbourhood='Hillcrest Village', Latitude=43.8037622, Longitude=-79.3634517)
# Pandas(Index=18, Postcode='M2J', Borough='North York', Neighbourhood='Fairview,Henry Farm,Oriole', Latitude=43.7785175, Longitude=-79.3465557)
# Pandas(Index=19, Postcode='M2K', Borough='North York', Neighbourhood='Bayview Village', Latitude=43.7869473, Longitude=-79.385975)
# Pandas(Index=20, Postcode='M2L', Borough='North York', Neighbourhood='Silver Hills,York Mills', Latitude=43.7574902, Longitude=-79.37471409999999)
# Pandas(Index=21, Postcode='M2M', Borough='North York', Neighbourhood='Newtonbrook,Willowdale', Latitude=43.789053, Longitude=-79.40849279999999)
# Pandas(Index=22, Postcode='M2N', Borough='North York', Neighbourhood='Willowdale South', Latitude=43.7701199, Longitude=-79.40849279999999)
# Pandas(Index=23, Postcode='M2P', Borough='North York', Neighbourhood='York Mills West', Latitude=43.752758299999996, Longitude=-79.4000493)
# Pandas(Index=24, Postcode='M2R', Borough='North York', Neighbourhood='Willowdale West', Latitude=43.7827364, Longitude=-79.4422593)
# Pandas(Index=25, Postcode='M3A', Borough='North York', Neighbourhood='Parkwoods', Latitude=43.7532586, Longitude=-79.3296565)
# Pandas(Index=26, Postcode='M3B', Borough='North York', Neighbourhood='Don Mills North', Latitude=43.745905799999996, Longitude=-79.352188)
# Pandas(Index=27, Postcode='M3C', Borough='North York', Neighbourhood='Flemingdon Park,Don Mills South', Latitude=43.72589970000001, Longitude=-79.340923)
# Pandas(Index=28, Postcode='M3H', Borough='North York', Neighbourhood='Bathurst Manor,Downsview North,Wilson Heights', Latitude=43.7543283, Longitude=-79.4422593)
# Pandas(Index=29, Postcode='M3J', Borough='North York', Neighbourhood='Northwood Park,York University', Latitude=43.7679803, Longitude=-79.48726190000001)
# Pandas(Index=30, Postcode='M3K', Borough='North York', Neighbourhood='CFB Toronto,Downsview East', Latitude=43.737473200000004, Longitude=-79.46476329999999)
# Pandas(Index=31, Postcode='M3L', Borough='North York', Neighbourhood='Downsview West', Latitude=43.7390146, Longitude=-79.5069436)
# Pandas(Index=32, Postcode='M3M', Borough='North York', Neighbourhood='Downsview Central', Latitude=43.7284964, Longitude=-79.49569740000001)
# Pandas(Index=33, Postcode='M3N', Borough='North York', Neighbourhood='Downsview Northwest', Latitude=43.7616313, Longitude=-79.52099940000001)
# Pandas(Index=34, Postcode='M4A', Borough='North York', Neighbourhood='Victoria Village', Latitude=43.725882299999995, Longitude=-79.31557159999998)
# Pandas(Index=35, Postcode='M4B', Borough='East York', Neighbourhood='Woodbine Gardens,Parkview Hill', Latitude=43.7063972, Longitude=-79.309937)
# Pandas(Index=36, Postcode='M4C', Borough='East York', Neighbourhood='Woodbine Heights', Latitude=43.695343900000005, Longitude=-79.3183887)
# Pandas(Index=37, Postcode='M4E', Borough='East Toronto', Neighbourhood='The Beaches', Latitude=43.67635739999999, Longitude=-79.2930312)
# Pandas(Index=38, Postcode='M4G', Borough='East York', Neighbourhood='Leaside', Latitude=43.7090604, Longitude=-79.3634517)
# Pandas(Index=39, Postcode='M4H', Borough='East York', Neighbourhood='Thorncliffe Park', Latitude=43.7053689, Longitude=-79.34937190000001)
# Pandas(Index=40, Postcode='M4J', Borough='East York', Neighbourhood='East Toronto', Latitude=43.685347, Longitude=-79.3381065)
# Pandas(Index=41, Postcode='M4K', Borough='East Toronto', Neighbourhood='The Danforth West,Riverdale', Latitude=43.6795571, Longitude=-79.352188)
# Pandas(Index=42, Postcode='M4L', Borough='East Toronto', Neighbourhood='The Beaches West,India Bazaar', Latitude=43.6689985, Longitude=-79.31557159999998)
# Pandas(Index=43, Postcode='M4M', Borough='East Toronto', Neighbourhood='Studio District', Latitude=43.6595255, Longitude=-79.340923)
# Pandas(Index=44, Postcode='M4N', Borough='Central Toronto', Neighbourhood='Lawrence Park', Latitude=43.7280205, Longitude=-79.3887901)
# Pandas(Index=45, Postcode='M4P', Borough='Central Toronto', Neighbourhood='Davisville North', Latitude=43.7127511, Longitude=-79.3901975)
# Pandas(Index=46, Postcode='M4R', Borough='Central Toronto', Neighbourhood='North Toronto West', Latitude=43.7153834, Longitude=-79.40567840000001)
# Pandas(Index=47, Postcode='M4S', Borough='Central Toronto', Neighbourhood='Davisville', Latitude=43.7043244, Longitude=-79.3887901)
# Pandas(Index=48, Postcode='M4T', Borough='Central Toronto', Neighbourhood='Moore Park,Summerhill East', Latitude=43.6895743, Longitude=-79.38315990000001)
# Pandas(Index=49, Postcode='M4V', Borough='Central Toronto', Neighbourhood='Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West', Latitude=43.68641229999999, Longitude=-79.4000493)
# Pandas(Index=50, Postcode='M4W', Borough='Downtown Toronto', Neighbourhood='Rosedale', Latitude=43.6795626, Longitude=-79.37752940000001)
# Pandas(Index=51, Postcode='M4X', Borough='Downtown Toronto', Neighbourhood='Cabbagetown,St. James Town', Latitude=43.667967, Longitude=-79.3676753)
# Pandas(Index=52, Postcode='M4Y', Borough='Downtown Toronto', Neighbourhood='Church and Wellesley', Latitude=43.6658599, Longitude=-79.38315990000001)
# Pandas(Index=53, Postcode='M5A', Borough='Downtown Toronto', Neighbourhood='Harbourfront,Regent Park', Latitude=43.6542599, Longitude=-79.3606359)
# Pandas(Index=54, Postcode='M5B', Borough='Downtown Toronto', Neighbourhood='Ryerson,Garden District', Latitude=43.6571618, Longitude=-79.37893709999999)
# Pandas(Index=55, Postcode='M5C', Borough='Downtown Toronto', Neighbourhood='St. James Town', Latitude=43.6514939, Longitude=-79.3754179)
# Pandas(Index=56, Postcode='M5E', Borough='Downtown Toronto', Neighbourhood='Berczy Park', Latitude=43.644770799999996, Longitude=-79.3733064)
# Pandas(Index=57, Postcode='M5G', Borough='Downtown Toronto', Neighbourhood='Central Bay Street', Latitude=43.6579524, Longitude=-79.3873826)
# Pandas(Index=58, Postcode='M5H', Borough='Downtown Toronto', Neighbourhood='Adelaide,King,Richmond', Latitude=43.65057120000001, Longitude=-79.3845675)
# Pandas(Index=59, Postcode='M5J', Borough='Downtown Toronto', Neighbourhood='Harbourfront East,Toronto Islands,Union Station', Latitude=43.6408157, Longitude=-79.38175229999999)
# Pandas(Index=60, Postcode='M5K', Borough='Downtown Toronto', Neighbourhood='Design Exchange,Toronto Dominion Centre', Latitude=43.6471768, Longitude=-79.38157640000001)
# Pandas(Index=61, Postcode='M5L', Borough='Downtown Toronto', Neighbourhood='Commerce Court,Victoria Hotel', Latitude=43.6481985, Longitude=-79.37981690000001)
# Pandas(Index=62, Postcode='M5M', Borough='North York', Neighbourhood='Bedford Park,Lawrence Manor East', Latitude=43.7332825, Longitude=-79.4197497)
# Pandas(Index=63, Postcode='M5N', Borough='Central Toronto', Neighbourhood='Roselawn', Latitude=43.7116948, Longitude=-79.41693559999999)
# Pandas(Index=64, Postcode='M5P', Borough='Central Toronto', Neighbourhood='Forest Hill North,Forest Hill West', Latitude=43.6969476, Longitude=-79.41130720000001)
# Pandas(Index=65, Postcode='M5R', Borough='Central Toronto', Neighbourhood='The Annex,North Midtown,Yorkville', Latitude=43.6727097, Longitude=-79.40567840000001)
# Pandas(Index=66, Postcode='M5S', Borough='Downtown Toronto', Neighbourhood='Harbord,University of Toronto', Latitude=43.6626956, Longitude=-79.4000493)
# Pandas(Index=67, Postcode='M5T', Borough='Downtown Toronto', Neighbourhood='Chinatown,Grange Park,Kensington Market', Latitude=43.6532057, Longitude=-79.4000493)
# Pandas(Index=68, Postcode='M5V', Borough='Downtown Toronto', Neighbourhood='CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara', Latitude=43.6289467, Longitude=-79.3944199)
# Pandas(Index=69, Postcode='M5W', Borough='Downtown Toronto', Neighbourhood='Stn A PO Boxes 25 The Esplanade', Latitude=43.6464352, Longitude=-79.37484599999999)
# Pandas(Index=70, Postcode='M5X', Borough='Downtown Toronto', Neighbourhood='First Canadian Place,Underground city', Latitude=43.6484292, Longitude=-79.3822802)
# Pandas(Index=71, Postcode='M6A', Borough='North York', Neighbourhood='Lawrence Heights,Lawrence Manor', Latitude=43.718517999999996, Longitude=-79.46476329999999)
# Pandas(Index=72, Postcode='M6B', Borough='North York', Neighbourhood='Glencairn', Latitude=43.709577, Longitude=-79.44507259999999)
# Pandas(Index=73, Postcode='M6C', Borough='York', Neighbourhood='Humewood-Cedarvale', Latitude=43.6937813, Longitude=-79.42819140000002)
# Pandas(Index=74, Postcode='M6E', Borough='York', Neighbourhood='Caledonia-Fairbanks', Latitude=43.6890256, Longitude=-79.453512)
# Pandas(Index=75, Postcode='M6G', Borough='Downtown Toronto', Neighbourhood='Christie', Latitude=43.669542, Longitude=-79.4225637)
# Pandas(Index=76, Postcode='M6H', Borough='West Toronto', Neighbourhood='Dovercourt Village,Dufferin', Latitude=43.66900510000001, Longitude=-79.4422593)
# Pandas(Index=77, Postcode='M6J', Borough='West Toronto', Neighbourhood='Little Portugal,Trinity', Latitude=43.647926700000006, Longitude=-79.4197497)
# Pandas(Index=78, Postcode='M6K', Borough='West Toronto', Neighbourhood='Brockton,Exhibition Place,Parkdale Village', Latitude=43.6368472, Longitude=-79.42819140000002)
# Pandas(Index=79, Postcode='M6L', Borough='North York', Neighbourhood='Downsview,North Park,Upwood Park', Latitude=43.713756200000006, Longitude=-79.4900738)
# Pandas(Index=80, Postcode='M6M', Borough='York', Neighbourhood='Del Ray,Keelesdale,Mount Dennis,Silverthorn', Latitude=43.6911158, Longitude=-79.47601329999999)
# Pandas(Index=81, Postcode='M6N', Borough='York', Neighbourhood='The Junction North,Runnymede', Latitude=43.67318529999999, Longitude=-79.48726190000001)
# Pandas(Index=82, Postcode='M6P', Borough='West Toronto', Neighbourhood='High Park,The Junction South', Latitude=43.6616083, Longitude=-79.46476329999999)
# Pandas(Index=83, Postcode='M6R', Borough='West Toronto', Neighbourhood='Parkdale,Roncesvalles', Latitude=43.6489597, Longitude=-79.456325)
# Pandas(Index=84, Postcode='M6S', Borough='West Toronto', Neighbourhood='Runnymede,Swansea', Latitude=43.6515706, Longitude=-79.4844499)
# Pandas(Index=85, Postcode='M7A', Borough="Queen's Park", Neighbourhood="Queen's Park", Latitude=43.6623015, Longitude=-79.3894938)
# Pandas(Index=86, Postcode='M7R', Borough='Mississauga', Neighbourhood='Canada Post Gateway Processing Centre', Latitude=43.6369656, Longitude=-79.61581899999999)
# Pandas(Index=87, Postcode='M7Y', Borough='East Toronto', Neighbourhood='Business Reply Mail Processing Centre 969 Eastern', Latitude=43.6627439, Longitude=-79.321558)
# Pandas(Index=88, Postcode='M8V', Borough='Etobicoke', Neighbourhood='Humber Bay Shores,Mimico South,New Toronto', Latitude=43.6056466, Longitude=-79.50132070000001)
# Pandas(Index=89, Postcode='M8W', Borough='Etobicoke', Neighbourhood='Alderwood,Long Branch', Latitude=43.60241370000001, Longitude=-79.54348409999999)
# Pandas(Index=90, Postcode='M8X', Borough='Etobicoke', Neighbourhood='The Kingsway,Montgomery Road,Old Mill North', Latitude=43.653653600000005, Longitude=-79.5069436)
# Pandas(Index=91, Postcode='M8Y', Borough='Etobicoke', Neighbourhood="Humber Bay,King's Mill Park,Kingsway Park South East,Mimico NE,Old Mill South,The Queensway East,Royal York South East,Sunnylea", Latitude=43.6362579, Longitude=-79.49850909999999)
# Pandas(Index=92, Postcode='M8Z', Borough='Etobicoke', Neighbourhood='Kingsway Park South West,Mimico NW,The Queensway West,Royal York South West,South of Bloor', Latitude=43.6288408, Longitude=-79.52099940000001)
# Pandas(Index=93, Postcode='M9A', Borough='Etobicoke', Neighbourhood='Islington Avenue', Latitude=43.6678556, Longitude=-79.53224240000002)
# Pandas(Index=94, Postcode='M9B', Borough='Etobicoke', Neighbourhood='Cloverdale,Islington,Martin Grove,Princess Gardens,West Deane Park', Latitude=43.6509432, Longitude=-79.55472440000001)
# Pandas(Index=95, Postcode='M9C', Borough='Etobicoke', Neighbourhood='Bloordale Gardens,Eringate,Markland Wood,Old Burnhamthorpe', Latitude=43.6435152, Longitude=-79.57720079999999)
# Pandas(Index=96, Postcode='M9L', Borough='North York', Neighbourhood='Humber Summit', Latitude=43.7563033, Longitude=-79.56596329999999)
# Pandas(Index=97, Postcode='M9M', Borough='North York', Neighbourhood='Emery,Humberlea', Latitude=43.7247659, Longitude=-79.53224240000002)
# Pandas(Index=98, Postcode='M9N', Borough='York', Neighbourhood='Weston', Latitude=43.706876, Longitude=-79.51818840000001)
# Pandas(Index=99, Postcode='M9P', Borough='Etobicoke', Neighbourhood='Westmount', Latitude=43.696319, Longitude=-79.53224240000002)
# Pandas(Index=100, Postcode='M9R', Borough='Etobicoke', Neighbourhood='Kingsview Village,Martin Grove Gardens,Richview Gardens,St. Phillips', Latitude=43.6889054, Longitude=-79.55472440000001)
# Pandas(Index=101, Postcode='M9V', Borough='Etobicoke', Neighbourhood='Albion Gardens,Beaumond Heights,Humbergate,Jamestown,Mount Olive,Silverstone,South Steeles,Thistletown', Latitude=43.739416399999996, Longitude=-79.5884369)
# Pandas(Index=102, Postcode='M9W', Borough='Etobicoke', Neighbourhood='Northwest', Latitude=43.706748299999994, Longitude=-79.5940544)

# %% [markdown]
# #### Display the combined dataframe

# %%
Combined_DF
# Out:
#     Postcode      Borough                                      Neighbourhood  \
# 0        M1B  Scarborough                                      Rouge,Malvern
# 1        M1C  Scarborough               Highland Creek,Rouge Hill,Port Union
# 2        M1E  Scarborough                    Guildwood,Morningside,West Hill
# 3        M1G  Scarborough                                             Woburn
# 4        M1H  Scarborough                                          Cedarbrae
# ..       ...          ...                                                ...
# 98       M9N         York                                             Weston
# 99       M9P    Etobicoke                                          Westmount
# 100      M9R    Etobicoke  Kingsview Village,Martin Grove Gardens,Richvie...
# 101      M9V    Etobicoke  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 102      M9W    Etobicoke                                          Northwest
#
#       Latitude  Longitude
# 0    43.806686 -79.194353
# 1    43.784535 -79.160497
# 2    43.763573 -79.188711
# 3    43.770992 -79.216917
# 4    43.773136 -79.239476
# ..         ...        ...
# 98   43.706876 -79.518188
# 99   43.696319 -79.532242
# 100  43.688905 -79.554724
# 101  43.739416 -79.588437
# 102  43.706748 -79.594054
#
# [103 rows x 5 columns]
